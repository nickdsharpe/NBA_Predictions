# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup, Comment
pd.set_option('display.max_columns', None)

full_df = pd.read_csv('nba_games.csv')
full_df
# Out:
#          fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb   drb  \
# 0      37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  36.0
# 1      37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800   7.0  33.0
# 2      38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  39.0
# 3      37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696   7.0  40.0
# 4      35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  25.0
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 19985  38.0  80.0  0.475  12.0  30.0  0.400  12.0  14.0  0.857   8.0  24.0
# 19986  34.0  78.0  0.436  13.0  31.0  0.419  24.0  27.0  0.889   8.0  28.0
# 19987  47.0  93.0  0.505  15.0  32.0  0.469  16.0  19.0  0.842  13.0  32.0
# 19988  47.0  91.0  0.516   9.0  28.0  0.321  10.0  16.0  0.625  11.0  34.0
# 19989  44.0  95.0  0.463  16.0  43.0  0.372  17.0  21.0  0.810  14.0  28.0
#
# ...

# %%
len(full_df.columns)
# Out:
# 137

# %%
SCORE_DIR = 'data/scores'

# %%
box_scores = os.listdir(SCORE_DIR)

# %%
box_scores = [os.path.join(SCORE_DIR, f) for f in box_scores if f.endswith('.html')]

# %%
def parse_html(box_score):
    try:
        with open(box_score, encoding='utf-8') as f:
            html = f.read()

            soup = BeautifulSoup(html)
            [s.decompose() for s in soup.select('tr.over_header')]
            [s.decompose() for s in soup.select('tr.thead')]
            return soup
    except(UnicodeDecodeError):
        pass

# %%
def read_line_score(soup):
    
    comments = soup.findAll(text=lambda text:isinstance(text,Comment))
    for comment in comments:
        if 'table' in comment:
            table_soup = BeautifulSoup(comment, 'html.parser')
            table = table_soup.find('table', {'id': 'line_score'})
            if table is not None:
                table = table
                break
    line_score = pd.read_html(str(table))[0]
    cols = list(line_score.columns)
    cols[0] = 'team'
    cols[-1] = 'total'
    line_score.columns = cols
    
    line_score = line_score[['team', 'total']]
    
    return line_score

# %%
def read_season_info(soup):
    
    nav = soup.select('#bottom_nav_container')[0]
    hrefs = [a['href'] for a in nav.find_all('a')]
    season = os.path.basename(hrefs[1]).split('_')[0]
    
    return season

# %%
def read_stats(soup, team, stat):
    
    df = pd.read_html(str(soup), attrs={'id' : f'box-{team}-game-{stat}'}, index_col=0)[0]
    df = df.apply(pd.to_numeric, errors='coerce')
    return df

# %%
base_cols = None
games = []

filtered_box_scores = [box_score for box_score in box_scores if '0326' in box_score]
for box_score in filtered_box_scores:
    
    try:
        soup = parse_html(box_score)
        line_score = read_line_score(soup)
        teams = list(line_score['team'])

        summaries = []
        for team in teams:
            basic = read_stats(soup, team, 'basic')
            advanced = read_stats(soup, team, 'advanced')

            totals = pd.concat([basic.iloc[-1,:], advanced.iloc[-1,:]])
            totals.index = totals.index.str.lower()
            maxes = pd.concat([basic.iloc[:-1,:].max(), advanced.iloc[:-1,:].max()])
            maxes.index = maxes.index.str.lower() + '_max'

            summary = pd.concat([totals, maxes])

            if base_cols is None:
                base_cols = list(summary.index.drop_duplicates(keep='first'))
                base_cols = [b for b in base_cols if 'bpm' not in b]

            summary = summary[base_cols]

            summaries.append(summary)

        summary = pd.concat(summaries, axis=1).T

        game = pd.concat([summary, line_score], axis=1)

        game['home'] = [0, 1]
        game_opp = game.iloc[::-1].reset_index()
        game_opp.columns += '_opp'

        full_game = pd.concat([game, game_opp], axis=1)

        full_game['season'] = read_season_info(soup)

        full_game['date'] = os.path.basename(box_score)[:8]
        full_game['date'] = pd.to_datetime(full_game['date'], format='%Y%m%d')

        full_game['won'] = full_game['total'] > full_game['total_opp']
        games.append(full_game)

        if len(games) % 100 == 0:
            print(f'{len(games)} / {len(box_scores)}')
    except:
        pass

# %%
games_df = pd.concat(games, ignore_index=True)
games_df
# Out:
#        mp     mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  \
# 0   240.0  240.0  48.0  89.0  0.539  13.0  33.0  0.394  14.0  19.0  0.737
# 1   240.0  240.0  45.0  98.0  0.459   7.0  31.0  0.226  22.0  26.0  0.846
# 2   240.0  240.0  36.0  97.0  0.371   8.0  36.0  0.222  13.0  18.0  0.722
# 3   240.0  240.0  52.0  91.0  0.571  18.0  44.0  0.409  15.0  21.0  0.714
# 4   240.0  240.0  32.0  84.0  0.381  19.0  49.0  0.388  21.0  22.0  0.955
# 5   240.0  240.0  39.0  88.0  0.443  12.0  29.0  0.414  20.0  24.0  0.833
# 6   240.0  240.0  35.0  80.0  0.438   6.0  25.0  0.240  15.0  18.0  0.833
# 7   240.0  240.0  39.0  83.0  0.470   9.0  30.0  0.300  21.0  24.0  0.875
# 8   240.0  240.0  34.0  80.0  0.425  17.0  40.0  0.425  14.0  25.0  0.560
# 9   240.0  240.0  34.0  82.0  0.415  15.0  40.0  0.375  13.0  17.0  0.765
# 10  240.0  240.0  47.0  87.0  0.540  14.0  31.0  0.452  10.0  13.0  0.769
# 11  240.0  240.0  38.0  75.0  0.507  13.0  36.0  0.361  19.0  28.0  0.679
# ...

# %%
removed_cols = ['mp', 'usg%', 'mp_opp', 'usg%_opp', 'index_opp','+/-', 'mp_max', '+/-_opp', 'mp_max_opp']
selected_columns = games_df.columns[~games_df.columns.isin(removed_cols)]
games_df = games_df[selected_columns]
nulls = pd.isnull(games_df)
nulls = nulls.sum()
nulls = nulls[nulls > 0]
valid_cols = games_df.columns[~games_df.columns.isin(nulls.index)]
games_df = games_df[valid_cols].copy()
games_df
# Out:
#       fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb   drb   trb  \
# 0   48.0  89.0  0.539  13.0  33.0  0.394  14.0  19.0  0.737   6.0  33.0  39.0
# 1   45.0  98.0  0.459   7.0  31.0  0.226  22.0  26.0  0.846  14.0  34.0  48.0
# 2   36.0  97.0  0.371   8.0  36.0  0.222  13.0  18.0  0.722   3.0  35.0  38.0
# 3   52.0  91.0  0.571  18.0  44.0  0.409  15.0  21.0  0.714   9.0  52.0  61.0
# 4   32.0  84.0  0.381  19.0  49.0  0.388  21.0  22.0  0.955   3.0  34.0  37.0
# 5   39.0  88.0  0.443  12.0  29.0  0.414  20.0  24.0  0.833  14.0  44.0  58.0
# 6   35.0  80.0  0.438   6.0  25.0  0.240  15.0  18.0  0.833  12.0  24.0  36.0
# 7   39.0  83.0  0.470   9.0  30.0  0.300  21.0  24.0  0.875  13.0  28.0  41.0
# 8   34.0  80.0  0.425  17.0  40.0  0.425  14.0  25.0  0.560   9.0  40.0  49.0
# 9   34.0  82.0  0.415  15.0  40.0  0.375  13.0  17.0  0.765   6.0  31.0  37.0
# 10  47.0  87.0  0.540  14.0  31.0  0.452  10.0  13.0  0.769   8.0  34.0  42.0
# ...

# %%
len(games_df.columns)
# Out:
# 137

# %%
full_df = full_df[selected_columns]
full_nulls = pd.isnull(full_df)
full_nulls = full_nulls.sum()
full_nulls = full_nulls[full_nulls > 0]
valid_cols = full_df.columns[~full_df.columns.isin(full_nulls.index)]
full_df = full_df[valid_cols].copy()
full_df
# Out:
#          fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb   drb  \
# 0      37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  36.0
# 1      37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800   7.0  33.0
# 2      38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  39.0
# 3      37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696   7.0  40.0
# 4      35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  25.0
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...   ...
# 19985  38.0  80.0  0.475  12.0  30.0  0.400  12.0  14.0  0.857   8.0  24.0
# 19986  34.0  78.0  0.436  13.0  31.0  0.419  24.0  27.0  0.889   8.0  28.0
# 19987  47.0  93.0  0.505  15.0  32.0  0.469  16.0  19.0  0.842  13.0  32.0
# 19988  47.0  91.0  0.516   9.0  28.0  0.321  10.0  16.0  0.625  11.0  34.0
# 19989  44.0  95.0  0.463  16.0  43.0  0.372  17.0  21.0  0.810  14.0  28.0
#
# ...

# %%
full = pd.concat([full_df, games_df], axis=0)
full
# Out:
#       fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb   drb   trb  \
# 0   37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  36.0  59.0
# 1   37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800   7.0  33.0  40.0
# 2   38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  39.0  50.0
# 3   37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696   7.0  40.0  47.0
# 4   35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  25.0  33.0
# ..   ...   ...    ...   ...   ...    ...   ...   ...    ...   ...   ...   ...
# 13  45.0  85.0  0.529   7.0  22.0  0.318  22.0  28.0  0.786   9.0  38.0  47.0
# 14  41.0  94.0  0.436  12.0  35.0  0.343  24.0  28.0  0.857  13.0  29.0  42.0
# 15  39.0  82.0  0.476  14.0  32.0  0.438  20.0  27.0  0.741   8.0  29.0  37.0
# 16  38.0  86.0  0.442  16.0  36.0  0.444  12.0  20.0  0.600  12.0  33.0  45.0
# 17  45.0  98.0  0.459  11.0  31.0  0.355  13.0  16.0  0.813  18.0  35.0  53.0
#
# ...

# %%
full.to_csv('nba_games.csv', index=False)
